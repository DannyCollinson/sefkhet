# %% [markdown]
# # Demo

# %%
import snaplog


for i, level in enumerate((-1, 0, 1, 9, 10, 11, 20, 30, 40, 50, 60, 61)):
    snaplog.record(
        "I <3 snaplog!",
        level=level,
        logger=(
            str(i),
            -10,
            {"handlers": ("stdout", {"level": -10}), "color": "level"},
        ),
    )
# Out:
# 2026-03-15 20:58:57,277 | LEVEL_1  | 2 | I <3 snaplog!
# 2026-03-15 20:58:57,278 | LEVEL_9  | 3 | I <3 snaplog!
# 2026-03-15 20:58:57,279 | DEBUG    | 4 | I <3 snaplog!
# 2026-03-15 20:58:57,280 | LEVEL_11 | 5 | I <3 snaplog!
# 2026-03-15 20:58:57,281 | INFO     | 6 | I <3 snaplog!
# 2026-03-15 20:58:57,281 | WARNING  | 7 | I <3 snaplog!
# 2026-03-15 20:58:57,282 | ERROR    | 8 | I <3 snaplog!
# 2026-03-15 20:58:57,285 | CRITICAL | 9 | I <3 snaplog!
# 2026-03-15 20:58:57,286 | LEVEL_60 | 10 | I <3 snaplog!
# 2026-03-15 20:58:57,287 | LEVEL_61 | 11 | I <3 snaplog!

# %%
logger = snaplog.SnapLogger()
