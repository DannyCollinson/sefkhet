# %% [markdown]
# # Demo

# %%
import sefkhet


for i, level in enumerate((-1, 0, 1, 9, 10, 11, 20, 30, 40, 50, 60, 61)):
    sefkhet.record(
        "I <3 sefkhet!",
        level=level,
        logger=(
            str(i),
            -10,
            {"handlers": ("stdout", {"level": -10}), "color": "level"},
        ),
    )
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import sefkhet
#       2
#       3
#       4 for i, level in enumerate((-1, 0, 1, 9, 10, 11, 20, 30, 40, 50, 60, 61)):
#
# File ~/projects/sefkhet/src/sefkhet/__init__.py:29
#      27 from sefkhet._color import ColorFormatter, get_level_color
#      28 from sefkhet._csv import CsvFormatter
# ---> 29 from sefkhet._functional import (
#      30     add_filters_to_target,
#      31     add_handlers_to_logger,
#      32     get_filter,
#      33     get_formatter,
#      34     get_handler,
#      35     get_log_level_map,
#      36     get_log_levels,
#      37     get_logger,
#      38 )
#      39 from sefkhet._json import JsonFormatter
#      40 from sefkhet._logfmt import LogfmtFormatter
#
# File ~/projects/sefkhet/src/sefkhet/_functional.py:6
#       3 import logging as _logging
#       4 from typing import TYPE_CHECKING as _TYPE_CHECKING
# ----> 6 from sefkhet._typing import _NoDefault
#       9 if _TYPE_CHECKING:  # pragma: no cover
#      10     import datetime
#
# File ~/projects/sefkhet/src/sefkhet/_typing.py:12
#      10 from ssl import SSLContext
#      11 from types import TracebackType
# ---> 12 from typing import (
#      13     Any,
#      14     Literal,
#      15     Protocol,
#      16     Required,
#      17     TextIO,
#      18     TypeVar,
#      19     TypedDict,
#      20     runtime_checkable,
#      21     type_check_only,
#      22 )
#      25 ########################################################################
#      26 # Default types
#      27 ########################################################################
#      30 class DefaultType:  # pylint: disable=too-few-public-methods
#
# ImportError: cannot import name 'type_check_only' from 'typing' (/home/danny/.local/share/uv/python/cpython-3.14.0-linux-x86_64-gnu/lib/python3.14/typing.py)

# %%
scribe = sefkhet.Scribe()
