# %% [markdown]
# # Demo

# %%
import snaplog


for i, level in enumerate((-1, 0, 1, 9, 10, 11, 20, 30, 40, 50, 60, 61)):
    snaplog.log(
        "I <3 snaplog!",
        level=level,
        logger=(
            str(i),
            -10,
            {"handlers": ("stdout", {"level": -10}), "color": "level"},
        ),
    )
# Out:
# 2026-02-19 21:09:09,835 | Level 1 | I <3 snaplog!
# 2026-02-19 21:09:09,836 | Level 9 | I <3 snaplog!
# 2026-02-19 21:09:09,837 | DEBUG | I <3 snaplog!
# 2026-02-19 21:09:09,838 | Level 11 | I <3 snaplog!
# 2026-02-19 21:09:09,838 | INFO | I <3 snaplog!
# 2026-02-19 21:09:09,839 | WARNING | I <3 snaplog!
# 2026-02-19 21:09:09,840 | ERROR | I <3 snaplog!
# 2026-02-19 21:09:09,840 | CRITICAL | I <3 snaplog!
# 2026-02-19 21:09:09,841 | Level 60 | I <3 snaplog!
# 2026-02-19 21:09:09,843 | Level 61 | I <3 snaplog!
