# %% [markdown]
# # Demo

# %%
import snaplog


for i, level in enumerate((-1, 0, 1, 9, 10, 11, 20, 30, 40, 50, 60, 61)):
    snaplog.log(
        "I <3 snaplog!",
        level=level,
        logger=(
            str(i),
            -10,
            {"handlers": ("stdout", {"level": -10}), "color": "level"},
        ),
    )
# Out:
# 2026-02-19 22:25:41,600 | LEVEL_1  | I <3 snaplog!
# 2026-02-19 22:25:41,602 | LEVEL_9  | I <3 snaplog!
# 2026-02-19 22:25:41,604 | DEBUG    | I <3 snaplog!
# 2026-02-19 22:25:41,606 | LEVEL_11 | I <3 snaplog!
# 2026-02-19 22:25:41,607 | INFO     | I <3 snaplog!
# 2026-02-19 22:25:41,609 | WARNING  | I <3 snaplog!
# 2026-02-19 22:25:41,611 | ERROR    | I <3 snaplog!
# 2026-02-19 22:25:41,613 | CRITICAL | I <3 snaplog!
# 2026-02-19 22:25:41,614 | LEVEL_60 | I <3 snaplog!
# 2026-02-19 22:25:41,615 | LEVEL_61 | I <3 snaplog!
