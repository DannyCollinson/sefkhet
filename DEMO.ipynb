# %% [markdown]
# # Demo

# %%
import snaplog


for i, level in enumerate((-1, 0, 1, 9, 10, 11, 20, 30, 40, 50, 60, 61)):
    snaplog.record(
        "I <3 snaplog!",
        level=level,
        logger=(
            str(i),
            -10,
            {"handlers": ("stdout", {"level": -10}), "color": "level"},
        ),
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
#       1 import snaplog
#       4 for i, level in enumerate((-1, 0, 1, 9, 10, 11, 20, 30, 40, 50, 60, 61)):
# ----> 5     snaplog.record(
#       6         "I <3 snaplog!",
#       7         level=level,
#       8         logger=(
#       9             str(i),
#      10             -10,
#      11             {"handlers": ("stdout", {"level": -10}), "color": "level"},
#      12         ),
#      13     )
#
# AttributeError: module 'snaplog' has no attribute 'record'
